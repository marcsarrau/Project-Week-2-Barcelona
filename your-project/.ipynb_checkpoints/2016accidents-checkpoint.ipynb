# %%
import pandas as pd
import numpy as np

# %%
accidents = pd.read_csv('../datasets/data/Question456/2017_accidents_persones_gu_bcn_.csv')
accidents.drop(['Codi_districte', 'Codi_barri', 'Nom_barri', 'Codi_carrer', 'Nom_carrer', 'Num_postal ', 'Dia_setmana', 'Descripcio_tipus_dia', 
                'Descripcio_situacio', 'Descripcio_causa_vianant', 'Coordenada_UTM_X', 'Coordenada_UTM_Y', 'Longitud', 'Latitud'], axis=1, inplace=True)
motocyclo_accidents = accidents[accidents['Desc_Tipus_vehicle_implicat'].isin(['Motocicleta', 'Ciclomotor'])]
motocyclo_accidents = motocyclo_accidents[motocyclo_accidents.Edat != "Desconegut"]
motocyclo_accidents = motocyclo_accidents[motocyclo_accidents.Nom_districte != "Desconegut"]
motocyclo_accidents = motocyclo_accidents[motocyclo_accidents.Descripcio_sexe != "Desconegut"]
motocyclo_accidents['Edat'] = motocyclo_accidents['Edat'].astype(str).astype(int)
motocyclo_accidents = motocyclo_accidents[['Any', 'Numero_expedient', 'Nom_districte', 'Descripcio_dia_setmana', 'Mes_ any', 'Nom_mes', 'Dia_mes', 'Descripcio_torn', 
                                           'Hora_dia', 'Desc_Tipus_vehicle_implicat', 'Descripcio_sexe', 'Edat', 'Descripcio_tipus_persona', 'Descripcio_victimitzacio']]

# %%
motocyclo_accidents
# Out:
#         Any Numero_expedient        Nom_districte Descripcio_dia_setmana  \
# 1      2017  2017S000002                 Eixample               Diumenge
# 2      2017  2017S000004                 Eixample               Diumenge
# 3      2017  2017S000005               Sant Martí               Diumenge
# 4      2017  2017S000005               Sant Martí               Diumenge
# 6      2017  2017S000008                 Eixample               Diumenge
# ...     ...              ...                  ...                    ...
# 12137  2017  2017S010775      Sarrià-Sant Gervasi               Dissabte
# 12139  2017  2017S010777                 Eixample               Dissabte
# 12140  2017  2017S010779                 Eixample               Diumenge
# 12142  2017  2017S010781               Sant Martí               Diumenge
# 12146  2017  2017S010783                 Eixample               Diumenge
#
#        Mes_ any   Nom_mes  Dia_mes Descripcio_torn  Hora_dia  \
# 1             1     Gener        1             Nit         2
# 2             1     Gener        1            Matí         7
# 3             1     Gener        1            Matí         7
# 4             1     Gener        1            Matí         7
# 6             1     Gener        1            Matí        10
# ...         ...       ...      ...             ...       ...
# 12137        12  Desembre       30             Nit        22
# 12139        12  Desembre       30           Tarda        21
# 12140        12  Desembre       31           Tarda        17
# 12142        12  Desembre       31           Tarda        18
# 12146        12  Desembre       31           Tarda        20
#
#       Desc_Tipus_vehicle_implicat Descripcio_sexe  Edat  \
# 1                     Motocicleta            Home    47
# 2                     Motocicleta            Dona    27
# 3                      Ciclomotor            Dona    40
# 4                      Ciclomotor            Home    37
# 6                     Motocicleta            Dona    31
# ...                           ...             ...   ...
# 12137                 Motocicleta            Home    23
# 12139                  Ciclomotor            Dona    29
# 12140                 Motocicleta            Home    46
# 12142                 Motocicleta            Home    17
# 12146                 Motocicleta            Home    31
#
#       Descripcio_tipus_persona  \
# 1                    Conductor
# 2                    Conductor
# 3                    Passatger
# 4                    Conductor
# 6                    Passatger
# ...                        ...
# 12137                Conductor
# 12139                Conductor
# 12140                Conductor
# 12142                Conductor
# 12146                Conductor
#
#                                 Descripcio_victimitzacio
# 1                                             Ferit lleu
# 2                                             Ferit lleu
# 3                                             Ferit lleu
# 4                                             Ferit lleu
# 6                                             Ferit lleu
# ...                                                  ...
# 12137             Ferit lleu: Hospitalització fins a 24h
# 12139  Ferit lleu: Amb assistència sanitària en lloc ...
# 12140             Ferit lleu: Hospitalització fins a 24h
# 12142             Ferit lleu: Hospitalització fins a 24h
# 12146             Ferit lleu: Hospitalització fins a 24h
#
# [6876 rows x 14 columns]

# %%
motocyclo_accidents['Nom_districte'].value_counts()
# Out:
# Eixample               2394
# Sant Martí              823
# Sarrià-Sant Gervasi     792
# Sants-Montjuïc          631
# Les Corts               507
# Horta-Guinardó          432
# Gràcia                  410
# Sant Andreu             309
# Ciutat Vella            305
# Nou Barris              273
# Name: Nom_districte, dtype: int64

# %%
motocyclo_accidents['Descripcio_dia_setmana'].value_counts()
# Out:
# Dimarts      1184
# Divendres    1179
# Dijous       1172
# Dimecres     1165
# Dilluns       943
# Dissabte      694
# Diumenge      539
# Name: Descripcio_dia_setmana, dtype: int64

# %%
motocyclo_accidents['Nom_mes'].value_counts()
# Out:
# Novembre    691
# Març        670
# Maig        626
# Juny        598
# Octubre     588
# Gener       588
# Febrer      573
# Juliol      564
# Desembre    540
# Setembre    525
# Abril       481
# Agost       432
# Name: Nom_mes, dtype: int64

# %%
motocyclo_accidents['Dia_mes'].value_counts()
# Out:
# 20    306
# 13    250
# 22    248
# 16    246
# 18    242
# 4     239
# 21    238
# 10    238
# 28    232
# 5     231
# 1     228
# 2     227
# 11    227
# 19    224
# 12    221
# 27    220
# 9     219
# 15    219
# 30    219
# 26    219
# 7     218
# 17    218
# 14    216
# 3     208
# 8     207
# 24    206
# 29    203
# 23    199
# 6     191
# 25    189
# 31    128
# Name: Dia_mes, dtype: int64

# %%
motocyclo_accidents['Hora_dia'].value_counts()
# Out:
# 14    543
# 15    480
# 9     462
# 18    460
# 19    449
# 13    445
# 16    439
# 8     431
# 12    411
# 20    409
# 17    396
# 21    375
# 11    306
# 10    301
# 22    253
# 7     189
# 23    150
# 0     118
# 1      78
# 6      72
# 5      40
# 2      30
# 3      20
# 4      19
# Name: Hora_dia, dtype: int64

# %%
motocyclo_accidents['Descripcio_torn'].value_counts()
# Out:
# Tarda    3551
# Matí     2617
# Nit       708
# Name: Descripcio_torn, dtype: int64

# %%
motocyclo_accidents['Desc_Tipus_vehicle_implicat'].value_counts()
# Out:
# Motocicleta    5878
# Ciclomotor      998
# Name: Desc_Tipus_vehicle_implicat, dtype: int64

# %%
motocyclo_accidents['Descripcio_sexe'].value_counts()
# Out:
# Home    4621
# Dona    2255
# Name: Descripcio_sexe, dtype: int64

# %%
motocyclo_accidents['Age'] = pd.cut(motocyclo_accidents['Edat'], bins=[0, 14, 20, 29, 39, 49, 59, 65, 75, 76], labels=["-14s", "15-20s", "21-29s","30-39s",
                                                                                                                        "40-49s", "50-59s", "60-65s", "66-75s", "+75s"])                                                                                    
motocyclo_accidents.groupby('Age')['Edat'].sum()
# Out:
# Age
# -14s        671
# 15-20s     7560
# 21-29s    48818
# 30-39s    64016
# 40-49s    61157
# 50-59s    45082
# 60-65s    12564
# 66-75s     7802
# +75s        380
# Name: Edat, dtype: int64

# %%
motocyclo_accidents['Descripcio_tipus_persona'].value_counts()
# Out:
# Conductor    5880
# Passatger     709
# Vianant       287
# Name: Descripcio_tipus_persona, dtype: int64

# %%
motocyclo_accidents['Descripcio_victimitzacio'].value_counts()
# Out:
# Ferit lleu: Hospitalització fins a 24h                      3281
# Ferit lleu                                                  1801
# Ferit lleu: Amb assistència sanitària en lloc d'accident    1531
# Ferit greu: hospitalització superior a 24h                   122
# Ferit lleu: Rebutja assistència sanitària                    104
# Ferit greu                                                    28
# Mort (dins 24h posteriors accident)                            7
# Mort                                                           2
# Name: Descripcio_victimitzacio, dtype: int64

# %%
motocyclo_accidents.groupby(['Nom_districte'])['Descripcio_victimitzacio'].count()
# Out:
# Nom_districte
# Ciutat Vella            305
# Eixample               2394
# Gràcia                  410
# Horta-Guinardó          432
# Les Corts               507
# Nou Barris              273
# Sant Andreu             309
# Sant Martí              823
# Sants-Montjuïc          631
# Sarrià-Sant Gervasi     792
# Name: Descripcio_victimitzacio, dtype: int64

# %%
districte_victimes = pd.crosstab(index=motocyclo_accidents['Nom_districte'], columns=motocyclo_accidents['Descripcio_victimitzacio'], 
                  values=motocyclo_accidents['Numero_expedient'], aggfunc='count')
districte_victimes.columns
# Out:
# Index(['Ferit greu', 'Ferit greu: hospitalització superior a 24h',
#        'Ferit lleu',
#        'Ferit lleu: Amb assistència sanitària en lloc d'accident',
#        'Ferit lleu: Hospitalització fins a 24h',
#        'Ferit lleu: Rebutja assistència sanitària', 'Mort',
#        'Mort (dins 24h posteriors accident)'],
#       dtype='object', name='Descripcio_victimitzacio')

# %%
districte_victimes
# Out:
# Descripcio_victimitzacio  Ferit greu  \
# Nom_districte
# Ciutat Vella                     NaN
# Eixample                        12.0
# Gràcia                           NaN
# Horta-Guinardó                   NaN
# Les Corts                        3.0
# Nou Barris                       3.0
# Sant Andreu                      1.0
# Sant Martí                       5.0
# Sants-Montjuïc                   NaN
# Sarrià-Sant Gervasi              4.0
#
# Descripcio_victimitzacio  Ferit greu: hospitalització superior a 24h  \
# Nom_districte
# Ciutat Vella                                                     4.0
# Eixample                                                        26.0
# Gràcia                                                           9.0
# Horta-Guinardó                                                   5.0
# Les Corts                                                       12.0
# Nou Barris                                                       6.0
# Sant Andreu                                                      5.0
# Sant Martí                                                      30.0
# Sants-Montjuïc                                                  13.0
# Sarrià-Sant Gervasi                                             12.0
#
# Descripcio_victimitzacio  Ferit lleu  \
# Nom_districte
# Ciutat Vella                    58.0
# Eixample                       628.0
# Gràcia                         100.0
# Horta-Guinardó                 130.0
# Les Corts                      147.0
# Nou Barris                      72.0
# Sant Andreu                     71.0
# Sant Martí                     203.0
# Sants-Montjuïc                 159.0
# Sarrià-Sant Gervasi            233.0
#
# Descripcio_victimitzacio  Ferit lleu: Amb assistència sanitària en lloc d'accident  \
# Nom_districte
# Ciutat Vella                                                           74.0
# Eixample                                                              594.0
# Gràcia                                                                 95.0
# Horta-Guinardó                                                         81.0
# Les Corts                                                             111.0
# Nou Barris                                                             59.0
# Sant Andreu                                                            60.0
# Sant Martí                                                            164.0
# Sants-Montjuïc                                                        127.0
# Sarrià-Sant Gervasi                                                   166.0
#
# Descripcio_victimitzacio  Ferit lleu: Hospitalització fins a 24h  \
# Nom_districte
# Ciutat Vella                                               157.0
# Eixample                                                  1101.0
# Gràcia                                                     198.0
# Horta-Guinardó                                             211.0
# Les Corts                                                  223.0
# Nou Barris                                                 129.0
# Sant Andreu                                                170.0
# Sant Martí                                                 409.0
# Sants-Montjuïc                                             317.0
# Sarrià-Sant Gervasi                                        366.0
#
# Descripcio_victimitzacio  Ferit lleu: Rebutja assistència sanitària  Mort  \
# Nom_districte
# Ciutat Vella                                                   12.0   NaN
# Eixample                                                       32.0   NaN
# Gràcia                                                          8.0   NaN
# Horta-Guinardó                                                  4.0   1.0
# Les Corts                                                       9.0   NaN
# Nou Barris                                                      3.0   1.0
# Sant Andreu                                                     2.0   NaN
# Sant Martí                                                     11.0   NaN
# Sants-Montjuïc                                                 12.0   NaN
# Sarrià-Sant Gervasi                                            11.0   NaN
#
# Descripcio_victimitzacio  Mort (dins 24h posteriors accident)
# Nom_districte
# Ciutat Vella                                              NaN
# Eixample                                                  1.0
# Gràcia                                                    NaN
# Horta-Guinardó                                            NaN
# Les Corts                                                 2.0
# Nou Barris                                                NaN
# Sant Andreu                                               NaN
# Sant Martí                                                1.0
# Sants-Montjuïc                                            3.0
# Sarrià-Sant Gervasi                                       NaN

# %%
districte_victimes.columns=[["Ferit lleu",
                                        "Ferit lleu: Amb assistència sanitària en lloc d'accident", 
                                        "Ferit lleu: Hospitalització fins a 24h",
                                        "Ferit lleu: hospitalització superior a 24h",
                                        "Ferit greu",
                                        "Ferit greu: hospitalització superior a 24h",
                                        "Mort",
                                        "Mort: (dins 24h posteriors accident)"]]

# %%
districte_victimes
# Out:
#                     Ferit lleu  \
# Nom_districte
# Ciutat Vella               NaN
# Eixample                  12.0
# Gràcia                     NaN
# Horta-Guinardó             NaN
# Les Corts                  3.0
# Nou Barris                 3.0
# Sant Andreu                1.0
# Sant Martí                 5.0
# Sants-Montjuïc             NaN
# Sarrià-Sant Gervasi        4.0
#
#                     Ferit lleu: Amb assistència sanitària en lloc d'accident  \
# Nom_districte
# Ciutat Vella                                                       4.0
# Eixample                                                          26.0
# Gràcia                                                             9.0
# Horta-Guinardó                                                     5.0
# Les Corts                                                         12.0
# Nou Barris                                                         6.0
# Sant Andreu                                                        5.0
# Sant Martí                                                        30.0
# Sants-Montjuïc                                                    13.0
# Sarrià-Sant Gervasi                                               12.0
#
#                     Ferit lleu: Hospitalització fins a 24h  \
# Nom_districte
# Ciutat Vella                                          58.0
# Eixample                                             628.0
# Gràcia                                               100.0
# Horta-Guinardó                                       130.0
# Les Corts                                            147.0
# Nou Barris                                            72.0
# Sant Andreu                                           71.0
# Sant Martí                                           203.0
# Sants-Montjuïc                                       159.0
# Sarrià-Sant Gervasi                                  233.0
#
#                     Ferit lleu: hospitalització superior a 24h Ferit greu  \
# Nom_districte
# Ciutat Vella                                              74.0      157.0
# Eixample                                                 594.0     1101.0
# Gràcia                                                    95.0      198.0
# Horta-Guinardó                                            81.0      211.0
# Les Corts                                                111.0      223.0
# Nou Barris                                                59.0      129.0
# Sant Andreu                                               60.0      170.0
# Sant Martí                                               164.0      409.0
# Sants-Montjuïc                                           127.0      317.0
# Sarrià-Sant Gervasi                                      166.0      366.0
#
#                     Ferit greu: hospitalització superior a 24h Mort  \
# Nom_districte
# Ciutat Vella                                              12.0  NaN
# Eixample                                                  32.0  NaN
# Gràcia                                                     8.0  NaN
# Horta-Guinardó                                             4.0  1.0
# Les Corts                                                  9.0  NaN
# Nou Barris                                                 3.0  1.0
# Sant Andreu                                                2.0  NaN
# Sant Martí                                                11.0  NaN
# Sants-Montjuïc                                            12.0  NaN
# Sarrià-Sant Gervasi                                       11.0  NaN
#
#                     Mort: (dins 24h posteriors accident)
# Nom_districte
# Ciutat Vella                                         NaN
# Eixample                                             1.0
# Gràcia                                               NaN
# Horta-Guinardó                                       NaN
# Les Corts                                            2.0
# Nou Barris                                           NaN
# Sant Andreu                                          NaN
# Sant Martí                                           1.0
# Sants-Montjuïc                                       3.0
# Sarrià-Sant Gervasi                                  NaN
